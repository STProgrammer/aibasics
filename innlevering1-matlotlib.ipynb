# %%
import random

# %%
r = random.random()

# %%
type(r)
# Out:
# float

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
rnd = np.random.uniform(-5,5, (1000,2))

# %%
plt.scatter(rnd[:,1] + np.sin(rnd[:,0]), rnd[:,1] - np.cos(rnd[:,1]))

# %%
print("Abdullah Karagøz")

# %%
sdfsdf

# %%
aa
